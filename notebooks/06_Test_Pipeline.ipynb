# %%
from pathlib import Path
import sys


PROJECT_ROOT = Path.cwd().parent


sys.path.append(
    str(PROJECT_ROOT)
)


print(PROJECT_ROOT)
# Out:
# /Users/rishabhtiwari/Desktop/ML Projects/Predictive_Maintenance_Project

# %%
from src.predict import predict_failure

# %%
import pandas as pd


sample = pd.DataFrame({

    "Type": ["L"],

    "Air temperature [K]": [300],

    "Process temperature [K]": [310],

    "Rotational speed [rpm]": [1500],

    "Torque [Nm]": [45],

    "Tool wear [min]": [120],

    "TWF": [0],

    "HDF": [0],

    "PWF": [0],

    "OSF": [0],

    "RNF": [0]

})


sample
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    L                  300                      310                    1500
#
#    Torque [Nm]  Tool wear [min]  TWF  HDF  PWF  OSF  RNF
# 0           45              120    0    0    0    0    0

# %%
prediction, probability = predict_failure(
    sample
)


print(
    "Machine Failure Prediction:",
    prediction
)


print(
    "Failure Probability:",
    round(probability*100,2),
    "%"
)
# Out:
# Machine Failure Prediction: 0
# Failure Probability: 4.0 %
